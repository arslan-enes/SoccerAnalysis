# %%
from statsbombpy import sb
import pandas as pd

# %%
competition_df = pd.DataFrame(sb.competitions())
competition_df.head()
# Out:
# C:\Users\enesf\anaconda3\lib\site-packages\statsbombpy\api_client.py:20: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn("credentials were not supplied. open data access only", NoAuthWarning)
#    competition_id  season_id country_name  competition_name  \
# 0              16          4       Europe  Champions League
# 1              16          1       Europe  Champions League
# 2              16          2       Europe  Champions League
# 3              16         27       Europe  Champions League
# 4              16         26       Europe  Champions League
#
#   competition_gender  competition_youth  competition_international  \
# 0               male              False                      False
# 1               male              False                      False
# 2               male              False                      False
# 3               male              False                      False
# 4               male              False                      False
#
#   season_name               match_updated        match_updated_360  \
# 0   2018/2019  2021-08-27T11:26:39.802832  2021-06-13T16:17:31.694
# 1   2017/2018  2021-08-27T11:26:39.802832  2021-06-13T16:17:31.694
# 2   2016/2017  2021-08-27T11:26:39.802832  2021-06-13T16:17:31.694
# 3   2015/2016  2021-08-27T11:26:39.802832  2021-06-13T16:17:31.694
# 4   2014/2015  2021-08-27T11:26:39.802832  2021-06-13T16:17:31.694
#
#   match_available_360             match_available
# 0                None     2021-07-09T14:06:05.802
# 1                None  2021-01-23T21:55:30.425330
# 2                None            2020-07-29T05:00
# 3                None            2020-07-29T05:00
# 4                None            2020-07-29T05:00

# %%
competition_df[competition_df.competition_name == 'FIFA World Cup']
# Competition id of the 2018 World Cup = 43, season id = 3
# Out:
#     competition_id  season_id   country_name competition_name  \
# 18              43          3  International   FIFA World Cup
#
#    competition_gender  competition_youth  competition_international  \
# 18               male              False                       True
#
#    season_name               match_updated        match_updated_360  \
# 18        2018  2021-12-06T23:11:59.985953  2021-06-13T16:17:31.694
#
#    match_available_360             match_available
# 18                None  2021-12-06T23:11:59.985953

# %%
world_cup_matches = pd.DataFrame(sb.matches(competition_id=43,season_id=3))
world_cup_matches.head()
# Out:
# C:\Users\enesf\anaconda3\lib\site-packages\statsbombpy\api_client.py:20: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn("credentials were not supplied. open data access only", NoAuthWarning)
#    match_id  match_date      kick_off                     competition season  \
# 0      7578  2018-06-15  14:00:00.000  International - FIFA World Cup   2018
# 1      7553  2018-06-23  17:00:00.000  International - FIFA World Cup   2018
# 2      7544  2018-06-20  17:00:00.000  International - FIFA World Cup   2018
# 3      7536  2018-06-18  17:00:00.000  International - FIFA World Cup   2018
# 4      7555  2018-06-24  20:00:00.000  International - FIFA World Cup   2018
#
#      home_team     away_team  home_score  away_score match_status  ...  \
# 0        Egypt       Uruguay           0           1    available  ...
# 1  South Korea        Mexico           1           2    available  ...
# 2      Uruguay  Saudi Arabia           1           0    available  ...
# 3      Belgium        Panama           3           0    available  ...
# 4       Poland      Colombia           0           3    available  ...
#
#           last_updated_360 match_week competition_stage  \
# 0  2021-06-13T16:17:31.694          1       Group Stage
# 1  2021-06-13T16:17:31.694          2       Group Stage
# 2  2021-06-13T16:17:31.694          2       Group Stage
# 3  2021-06-13T16:17:31.694          1       Group Stage
# 4  2021-06-13T16:17:31.694          2       Group Stage
#
#                      stadium                        referee  \
# 0         Ekaterinburg Arena                  Björn Kuipers
# 1               Rostov Arena                  Milorad Mažić
# 2               Rostov Arena                 Clément Turpin
# 3  Olimpiyskiy Stadion Fisht                  Janny Sikazwe
# 4              Kazan'' Arena  César Arturo Ramos Palazuelos
#
#                     home_managers                   away_managers  \
# 0               Héctor Raúl Cúper  Óscar Washington Tabárez Silva
# 1                   Tae-Yong Shin     Juan Carlos Osorio Arbeláez
# 2  Óscar Washington Tabárez Silva      Juan Antonio Pizzi Torroja
# 3       Roberto Martínez Montoliú    Hernán Darío Gómez Jaramillo
# 4                    Adam Nawałka            José Néstor Pekerman
#
#   data_version shot_fidelity_version xy_fidelity_version
# 0        1.0.2                  None                None
# 1        1.0.2                  None                None
# 2        1.0.2                  None                None
# 3        1.0.2                  None                None
# 4        1.0.2                  None                None
#
# [5 rows x 22 columns]

# %%
world_cup_matches[world_cup_matches.home_team=='Argentina']
# Argentina vs Crotia match id 7545
# Out:
#     match_id  match_date      kick_off                     competition season  \
# 30      7545  2018-06-21  20:00:00.000  International - FIFA World Cup   2018
# 34      7531  2018-06-16  15:00:00.000  International - FIFA World Cup   2018
#
#     home_team away_team  home_score  away_score match_status  ...  \
# 30  Argentina   Croatia           0           3    available  ...
# 34  Argentina   Iceland           1           1    available  ...
#
#            last_updated_360 match_week competition_stage  \
# 30  2021-06-13T16:17:31.694          2       Group Stage
# 34  2021-06-13T16:17:31.694          1       Group Stage
#
#                      stadium           referee             home_managers  \
# 30   Stadion Nizhny Novgorod   Ravshan Irmatov  Jorge Luis Sampaoli Moya
# 34  Otkrytiye Arena (Moskva)  Szymon Marciniak  Jorge Luis Sampaoli Moya
#
#           away_managers data_version shot_fidelity_version xy_fidelity_version
# 30         Zlatko Dalić        1.0.2                  None                None
# 34  Heimir Hallgrímsson        1.0.2                  None                None
#
# [2 rows x 22 columns]

# %%
arg_cro = pd.DataFrame(sb.events(7545))
arg_cro.head()
# Out:
# C:\Users\enesf\anaconda3\lib\site-packages\statsbombpy\api_client.py:20: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn("credentials were not supplied. open data access only", NoAuthWarning)
#   50_50 bad_behaviour_card ball_receipt_outcome ball_recovery_offensive  \
# 0   NaN                NaN                  NaN                     NaN
# 1   NaN                NaN                  NaN                     NaN
# 2   NaN                NaN                  NaN                     NaN
# 3   NaN                NaN                  NaN                     NaN
# 4   NaN                NaN                  NaN                     NaN
#
#   ball_recovery_recovery_failure carry_end_location clearance_aerial_won  \
# 0                            NaN                NaN                  NaN
# 1                            NaN                NaN                  NaN
# 2                            NaN                NaN                  NaN
# 3                            NaN                NaN                  NaN
# 4                            NaN                NaN                  NaN
#
#   counterpress dribble_nutmeg dribble_outcome  ... shot_statsbomb_xg  \
# 0          NaN            NaN             NaN  ...               NaN
# 1          NaN            NaN             NaN  ...               NaN
# 2          NaN            NaN             NaN  ...               NaN
# 3          NaN            NaN             NaN  ...               NaN
# 4          NaN            NaN             NaN  ...               NaN
#
#   shot_technique shot_type  substitution_outcome substitution_replacement  \
# 0            NaN       NaN                   NaN                      NaN
# 1            NaN       NaN                   NaN                      NaN
# 2            NaN       NaN                   NaN                      NaN
# 3            NaN       NaN                   NaN                      NaN
# 4            NaN       NaN                   NaN                      NaN
#
#                                              tactics       team     timestamp  \
# 0  {'formation': 3421, 'lineup': [{'player': {'id...  Argentina  00:00:00.000
# 1  {'formation': 4141, 'lineup': [{'player': {'id...    Croatia  00:00:00.000
# 2                                                NaN    Croatia  00:00:00.000
# 3                                                NaN  Argentina  00:00:00.000
# 4                                                NaN    Croatia  00:00:00.000
#
#           type under_pressure
# 0  Starting XI            NaN
# 1  Starting XI            NaN
# 2   Half Start            NaN
# 3   Half Start            NaN
# 4   Half Start            NaN
#
# [5 rows x 80 columns]

# %% [markdown]
# Creating the shot map

# %%
shots = arg_cro[arg_cro.type == 'Shot'].set_index('id')

# %%
import numpy as np
import matplotlib.pyplot as plt
from FCPython import createPitch
from copy import copy

# %%
pitch_width = 120
pitch_height = 80
fig,ax = createPitch(pitch_width,pitch_height,'yards','gray')

# %%
fig

# %%
#a = plt.Circle((1,2),5)
#ax.add_patch(a)
#fig

# %%
home_team = 'Argentina'
away_team = 'Croatia'

# %%
for i,shot in shots.iterrows():
    x = shot['location'][0]
    y = shot['location'][1]

    goal = shot['shot_outcome']=='Goal'
    team_name = shot['team']

    circle_size = 2
    circle_size = np.sqrt(shot['shot_statsbomb_xg']*15)

    if team_name == home_team:
        if goal:
            shot_circle = plt.Circle((x,pitch_height-y),circle_size,color = 'red')
            plt.text((x+1),pitch_height-y+1,shot['player'])
        else:
            shot_circle = plt.Circle((x,pitch_height-y),circle_size,color = 'red')
            shot_circle.set_alpha(.2)
    
    if team_name == away_team:
        if goal:
            shot_circle = plt.Circle((pitch_width-x,y),circle_size,color = 'blue')
            plt.text((pitch_width-x+1),y+1,shot['player'])

        else:
            shot_circle = plt.Circle((pitch_width-x,y),circle_size,color = 'blue')
            shot_circle.set_alpha(.2)
        
    ax.add_patch(shot_circle)

plt.text(5,75,away_team + 'shots')
plt.text(5,75,home_team + 'shots')

plt.title('Argentina vs Croatia')

fig.set_size_inches(10, 7)
fig.savefig('ARG_CRO_2018_WC_SHOTMAP.png', dpi=300)

# %%
len(shots)
# Out:
# 24
